# %%
import numpy as np
import numpy.ma as ma
import matplotlib.pyplot as plt
import astropy.units as u
from astropy.io import fits
from astropy.stats import sigma_clipped_stats, sigma_clip
from astropy.table import Table
from astropy.coordinates import SkyCoord
from astropy.wcs import WCS
from astropy.visualization import ZScaleInterval
from astroquery.vizier import Vizier
import subprocess
import os

# %%
def test_dependency(dep, alternate_name=None):
    """
    Test external dependency by trying to run it as a subprocess
    """
    try:
        subprocess.check_output(dep, stderr=subprocess.PIPE, shell=True)
        print("%s is installed properly as %s. OK" % (dep, dep))
        return 1
    except subprocess.CalledProcessError:
        try:
            subprocess.check_output(alternate_name, stderr=subprocess.PIPE, shell=True)
            print("%s is installed properly as %s. OK" % (dep, alternate_name))
            return 1
        except subprocess.CalledProcessError:
            print("===%s/%s IS NOT YET INSTALLED PROPERLY===" % (dep, alternate_name))
            return 0
    
dependencies = [('source-extractor', 'sex'), ('psfex', 'PSFEx')]
i = 0
for dep_name1, dep_name2 in dependencies:
    i += test_dependency(dep_name1, dep_name2)
print("%i out of %i external dependencies installed properly.\n" % (i, len(dependencies)))
if i != len(dependencies):
    print("Please correctly install these programs before continuing by following the instructions in README.md.")
else:
    print("You are ready to continue.")
# Out:
# source-extractor is installed properly as sex. OK
# psfex is installed properly as psfex. OK
# 2 out of 2 external dependencies installed properly.
#
# You are ready to continue.

# %%
# os.chdir('/home/welcome/KSP/photometry/files_TASK_2')
imageName = '20230525184701-216-RA.wcs.proc.fits'

with fits.open(imageName) as HDUList:
    header = HDUList[0].header
    image = HDUList[0].data

zscale = ZScaleInterval().get_limits(image)

plt.figure(figsize=(10,10))
plt.imshow(image, cmap='gray', origin='lower', vmin=zscale[0], vmax=zscale[1])
plt.colorbar()
plt.show()

# %%
w = WCS(header)
(raImage, decImage) = w.all_pix2world(image.shape[0]/2, image.shape[1]/2, 1)
boxsize = 30 # arcminutes
maxmag = 18

catNum = 'II/349'
print(f'\nQuerying Vizier {catNum} around RA {raImage:.4f}, Dec {decImage:.4f} with a radius of {boxsize} arcmin')

try:
    # You can set the filters for the individual columns (magnitude range, number of detections) inside the Vizier query
    v = Vizier(columns=['*'], column_filters={"gmag":f"<{maxmag}", "Nd":">6", "e_gmag":f"<{1.086/3}"}, row_limit=-1)
    Q = v.query_region(SkyCoord(ra=raImage, dec=decImage, unit=(u.deg, u.deg)), radius=str(boxsize)+'m', catalog=catNum, cache=False)
    print(Q[0])
except:
    print('I cannnot reach the Vizier database. Is the internet working?')
# Out:
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60089.782653 from DATE-OBS'. [astropy.wcs.wcs]
# Querying Vizier II/349 around RA 211.1014, Dec 54.3133 with a radius of 30 arcmin
#    RAJ2000       DEJ2000          objID        ...  yKmag  e_yKmag yFlags
#      deg           deg                         ...   mag     mag
# ------------- ------------- ------------------ ... ------- ------- ------
# 210.663724090  53.919290610 172702106637313866 ... 16.4559  0.0164 115000
# 210.663539540  53.892741500 172672106635471999 ... 16.3082  0.0166 115000
# 210.604486980  53.926405740 172712106044792397 ... 16.4376  0.0142 115000
# 210.625757450  53.949266840 172732106257949830 ... 13.8435  0.0035 115000
# 210.559704780  53.937696580 172722105596905934 ... 15.5672  0.0071 115000
# 210.439170920  54.003287860 172802104391914650 ... 14.9887  0.0043 115000
# 210.447712130  54.046944570 172852104477077040 ... 14.0260  0.0031 115000
# 210.394009680  54.069378840 172882103939893987 ... 15.2874  0.0041 115000
# 210.377594030  54.093628720 172912103775753110 ... 13.8098  0.0052 115000
# 211.551848240  53.914855810 172692115517798643 ... 13.7540  0.0019 115000
#           ...           ...                ... ...     ...     ...    ...
# 211.389644660  54.709108870 173652113897101556 ... 14.3704  0.0030 115000
# 211.383188040  54.721429910 173662113832166340 ... 14.7420  0.0198 115000
# 211.447903520  54.683426060 173622114479190746 ... 16.5702  0.0106 115000
# 211.397292700  54.731710700 173672113972788684 ... 16.2727  0.0165 115000
# 211.450513470  54.748214270 173692114504318428 ... 14.5338  0.0032 115000
# 211.418571590  54.758291300 173712114185810617 ... 14.8753  0.0026 115000
# 211.325299540  54.736859470 173682113252044964 ... 12.9410  0.0051 115000
# 211.341417080  54.752394860 173702113414513525 ... 14.2975  0.0106 115000
# 211.320961040  54.795940480 173752113209525801 ... 16.4233  0.0113 115000
# 211.312292400  54.789897370 173742113123078539 ... 14.0685  0.0011 115000
# Length = 634 rows

# %%
Q[0].meta['desc'] = Q[0].meta.pop('description')
Q[0].write('ps1Catalog.fits', format='fits', overwrite=True)

# %%
ps1_imCoords = w.all_world2pix(Q[0]['RAJ2000'], Q[0]['DEJ2000'], 1)
good_cat_stars = Q[0][np.where((ps1_imCoords[0] > 500) & (ps1_imCoords[0] < 3500) & (ps1_imCoords[1] > 500) & (ps1_imCoords[1] < 3500))]
ps1_imCoords = w.all_world2pix(good_cat_stars['RAJ2000'],good_cat_stars['DEJ2000'], 1)

fig = plt.figure(figsize=(10,10))
ax = fig.gca()
plt.imshow(image, cmap='gray', vmin=zscale[0], vmax=zscale[1])
circles = [plt.Circle((ps1_imCoords[0][i], ps1_imCoords[1][i]), radius = 10, edgecolor='C1', facecolor='None') for i in range(len(ps1_imCoords[0]))]
for c in circles:
    ax.add_artist(c)
    
plt.show()

# %%
configFile = 'photomCat.sex'
catalogName = imageName + '.cat'
paramName = 'photomCat.param'
try:
    command = f'sex -c {configFile} {imageName} -CATALOG_NAME {catalogName} -PARAMETERS_NAME {paramName}'
    print(f'Executing command: {command}')
    rval = subprocess.run(command.split(), check=True)
except subprocess.CalledProcessError as err:
    print(f'Could not run sextractor with exit error {err}')
# Out:
# Executing command: sex -c photomCat.sex 20230525184701-216-RA.wcs.proc.fits -CATALOG_NAME 20230525184701-216-RA.wcs.proc.fits.cat -PARAMETERS_NAME photomCat.param
# >
# ----- SExtractor 2.28.0 started on 2024-06-24 at 21:20:55 with 1 thread
#
# > Setting catalog parameters
# > Reading detection filter
# > Initializing Neural Network
# > Reading Neural Network Weights
# > Initializing catalog
# > Looking for 20230525184701-216-RA.wcs.proc.fits
# ----- Measuring from: 20230525184701-216-RA.wcs.proc.fits
#       "SN2023ixf" / no ext. header / 4096x4108 / 64 bits (floats)
# Detection+Measurement image: > Setting up background maps
# > Setting up background map at line: 1024
# > Setting up background map at line: 2048
# > Setting up background map at line: 3072
# > Setting up background map at line: 4096
# > Filtering background map(s)
# > Computing background d-map
# > Computing background-noise d-map
# (M+D) Background: 0          RMS: 11.3107    / Threshold: 113.107
# > Scanning image
# > Line:   25  Objects:        4 detected /        0 sextracted
# > Line:   50  Objects:        4 detected /        0 sextracted
# > Line:   75  Objects:        5 detected /        0 sextracted
# > Line:  100  Objects:        6 detected /        0 sextracted
# > Line:  125  Objects:        7 detected /        0 sextracted
# > Line:  150  Objects:       10 detected /        0 sextracted
# > Line:  175  Objects:       12 detected /        0 sextracted
# > Line:  200  Objects:       14 detected /        0 sextracted
# > Line:  225  Objects:       15 detected /        0 sextracted
# > Line:  250  Objects:       17 detected /        0 sextracted
# > Line:  275  Objects:       18 detected /        0 sextracted
# > Line:  300  Objects:       19 detected /        0 sextracted
# > Line:  325  Objects:       22 detected /        0 sextracted
# > Line:  350  Objects:       23 detected /        0 sextracted
# > Line:  375  Objects:       26 detected /        0 sextracted
# > Line:  400  Objects:       28 detected /        0 sextracted
# > Line:  425  Objects:       30 detected /        0 sextracted
# > Line:  450  Objects:       32 detected /        0 sextracted
# > Line:  475  Objects:       33 detected /        0 sextracted
# > Line:  500  Objects:       35 detected /        0 sextracted
# > Line:  525  Objects:       37 detected /        0 sextracted
# > Line:  550  Objects:       41 detected /        0 sextracted
# > Line:  575  Objects:       43 detected /        0 sextracted
# > Line:  600  Objects:       45 detected /        0 sextracted
# > Line:  625  Objects:       47 detected /        0 sextracted
# > Line:  650  Objects:       47 detected /        0 sextracted
# > Line:  675  Objects:       49 detected /        0 sextracted
# > Line:  700  Objects:       52 detected /        0 sextracted
# > Line:  725  Objects:       55 detected /        0 sextracted
# > Line:  750  Objects:       56 detected /        0 sextracted
# > Line:  775  Objects:       57 detected /        0 sextracted
# > Line:  800  Objects:       60 detected /        0 sextracted
# > Line:  825  Objects:       60 detected /        0 sextracted
# > Line:  850  Objects:       66 detected /        0 sextracted
# > Line:  875  Objects:       68 detected /        0 sextracted
# > Line:  900  Objects:       69 detected /        0 sextracted
# > Line:  925  Objects:       71 detected /        0 sextracted
# > Line:  950  Objects:       77 detected /        0 sextracted
# > Line:  975  Objects:       78 detected /        0 sextracted
# > Line: 1000  Objects:       80 detected /        0 sextracted
# > Line: 1023  Objects:       82 detected /        0 sextracted
# > Line: 1025  Objects:       82 detected /        4 sextracted
# > Line: 1050  Objects:       85 detected /        4 sextracted
# > Line: 1075  Objects:       87 detected /        5 sextracted
# > Line: 1100  Objects:       92 detected /        6 sextracted
# > Line: 1125  Objects:       92 detected /        7 sextracted
# > Line: 1150  Objects:       93 detected /       10 sextracted
# > Line: 1175  Objects:       94 detected /       12 sextracted
# > Line: 1200  Objects:       97 detected /       14 sextracted
# > Line: 1225  Objects:       98 detected /       15 sextracted
# > Line: 1250  Objects:      100 detected /       16 sextracted
# > Line: 1275  Objects:      105 detected /       18 sextracted
# > Line: 1300  Objects:      107 detected /       19 sextracted
# > Line: 1325  Objects:      113 detected /       22 sextracted
# > Line: 1350  Objects:      115 detected /       23 sextracted
# > Line: 1375  Objects:      117 detected /       25 sextracted
# > Line: 1400  Objects:      119 detected /       27 sextracted
# > Line: 1425  Objects:      122 detected /       30 sextracted
# > Line: 1450  Objects:      124 detected /       32 sextracted
# > Line: 1475  Objects:      128 detected /       33 sextracted
# > Line: 1500  Objects:      129 detected /       35 sextracted
# > Line: 1525  Objects:      133 detected /       36 sextracted
# > Line: 1550  Objects:      136 detected /       41 sextracted
# > Line: 1575  Objects:      138 detected /       43 sextracted
# > Line: 1600  Objects:      138 detected /       45 sextracted
# > Line: 1625  Objects:      142 detected /       47 sextracted
# > Line: 1650  Objects:      145 detected /       49 sextracted
# > Line: 1675  Objects:      147 detected /       49 sextracted
# > Line: 1700  Objects:      148 detected /       51 sextracted
# > Line: 1725  Objects:      149 detected /       55 sextracted
# > Line: 1750  Objects:      152 detected /       57 sextracted
# > Line: 1775  Objects:      154 detected /       58 sextracted
# > Line: 1800  Objects:      156 detected /       60 sextracted
# > Line: 1825  Objects:      161 detected /       61 sextracted
# > Line: 1850  Objects:      163 detected /       65 sextracted
# > Line: 1875  Objects:      165 detected /       67 sextracted
# > Line: 1900  Objects:      170 detected /       68 sextracted
# > Line: 1925  Objects:      171 detected /       71 sextracted
# > Line: 1950  Objects:      174 detected /       74 sextracted
# > Line: 1975  Objects:      177 detected /       77 sextracted
# > Line: 2000  Objects:      178 detected /       78 sextracted
# > Line: 2025  Objects:      181 detected /       81 sextracted
# > Line: 2050  Objects:      183 detected /       83 sextracted
# > Line: 2075  Objects:      185 detected /       87 sextracted
# > Line: 2100  Objects:      187 detected /       91 sextracted
# > Line: 2125  Objects:      193 detected /       91 sextracted
# > Line: 2150  Objects:      194 detected /       91 sextracted
# > Line: 2175  Objects:      198 detected /       93 sextracted
# > Line: 2200  Objects:      202 detected /       97 sextracted
# > Line: 2225  Objects:      203 detected /       98 sextracted
# > Line: 2250  Objects:      206 detected /       99 sextracted
# > Line: 2275  Objects:      210 detected /      105 sextracted
# > Line: 2300  Objects:      213 detected /      106 sextracted
# > Line: 2325  Objects:      216 detected /      111 sextracted
# > Line: 2350  Objects:      220 detected /      115 sextracted
# > Line: 2375  Objects:      220 detected /      115 sextracted
# > Line: 2400  Objects:      223 detected /      117 sextracted
# > Line: 2425  Objects:      223 detected /      120 sextracted
# > Line: 2450  Objects:      223 detected /      122 sextracted
# > Line: 2475  Objects:      225 detected /      126 sextracted
# > Line: 2500  Objects:      227 detected /      126 sextracted
# > Line: 2525  Objects:      230 detected /      131 sextracted
# > Line: 2550  Objects:      235 detected /      134 sextracted
# > Line: 2575  Objects:      237 detected /      136 sextracted
# > Line: 2600  Objects:      242 detected /      136 sextracted
# > Line: 2625  Objects:      246 detected /      141 sextracted
# > Line: 2650  Objects:      249 detected /      143 sextracted
# > Line: 2675  Objects:      249 detected /      145 sextracted
# > Line: 2700  Objects:      250 detected /      146 sextracted
# > Line: 2725  Objects:      254 detected /      148 sextracted
# > Line: 2750  Objects:      257 detected /      151 sextracted
# > Line: 2775  Objects:      258 detected /      152 sextracted
# > Line: 2800  Objects:      260 detected /      155 sextracted
# > Line: 2825  Objects:      263 detected /      159 sextracted
# > Line: 2850  Objects:      265 detected /      160 sextracted
# > Line: 2875  Objects:      269 detected /      164 sextracted
# > Line: 2900  Objects:      270 detected /      167 sextracted
# > Line: 2925  Objects:      272 detected /      169 sextracted
# > Line: 2950  Objects:      276 detected /      171 sextracted
# > Line: 2975  Objects:      278 detected /      175 sextracted
# > Line: 3000  Objects:      283 detected /      176 sextracted
# > Line: 3025  Objects:      287 detected /      178 sextracted
# > Line: 3050  Objects:      289 detected /      182 sextracted
# > Line: 3075  Objects:      292 detected /      183 sextracted
# > Line: 3100  Objects:      298 detected /      185 sextracted
# > Line: 3125  Objects:      299 detected /      192 sextracted
# > Line: 3150  Objects:      302 detected /      193 sextracted
# > Line: 3175  Objects:      302 detected /      195 sextracted
# > Line: 3200  Objects:      309 detected /      200 sextracted
# > Line: 3225  Objects:      309 detected /      201 sextracted
# > Line: 3250  Objects:      311 detected /      203 sextracted
# > Line: 3275  Objects:      315 detected /      206 sextracted
# > Line: 3300  Objects:      321 detected /      211 sextracted
# > Line: 3325  Objects:      323 detected /      214 sextracted
# > Line: 3350  Objects:      325 detected /      218 sextracted
# > Line: 3375  Objects:      326 detected /      218 sextracted
# > Line: 3400  Objects:      327 detected /      221 sextracted
# > Line: 3425  Objects:      328 detected /      221 sextracted
# > Line: 3450  Objects:      331 detected /      221 sextracted
# > Line: 3475  Objects:      336 detected /      223 sextracted
# > Line: 3500  Objects:      340 detected /      225 sextracted
# > Line: 3525  Objects:      343 detected /      228 sextracted
# > Line: 3550  Objects:      346 detected /      233 sextracted
# > Line: 3575  Objects:      349 detected /      236 sextracted
# > Line: 3600  Objects:      352 detected /      241 sextracted
# > Line: 3625  Objects:      353 detected /      244 sextracted
# > Line: 3650  Objects:      356 detected /      247 sextracted
# > Line: 3675  Objects:      357 detected /      247 sextracted
# > Line: 3700  Objects:      357 detected /      248 sextracted
# > Line: 3725  Objects:      359 detected /      253 sextracted
# > Line: 3750  Objects:      359 detected /      256 sextracted
# > Line: 3775  Objects:      361 detected /      256 sextracted
# > Line: 3800  Objects:      362 detected /      260 sextracted
# > Line: 3825  Objects:      365 detected /      262 sextracted
# > Line: 3850  Objects:      367 detected /      262 sextracted
# > Line: 3875  Objects:      369 detected /      262 sextracted
# > Line: 3900  Objects:      372 detected /      262 sextracted
# > Line: 3925  Objects:      373 detected /      262 sextracted
# > Line: 3950  Objects:      374 detected /      262 sextracted
# > Line: 3975  Objects:      375 detected /      262 sextracted
# > Line: 4000  Objects:      376 detected /      262 sextracted
# > Line: 4025  Objects:      376 detected /      262 sextracted
# > Line: 4050  Objects:      377 detected /      262 sextracted
# > Line: 4075  Objects:      377 detected /      262 sextracted
# > Line: 4100  Objects:      377 detected /      262 sextracted
#       Objects: detected 377      / sextracted 374
#
# > Closing files
# >
# > All done (in 0.5 s: 8549.5 lines/s , 778.4 detections/s)

# %%
with fits.open(catalogName) as HDU:
    print(HDU.info())
    sourceTable = Table(HDU[2].data)

print(sourceTable.colnames)
print(sourceTable)

cleanSources = sourceTable[(sourceTable['FLAGS']==0) & (sourceTable['FWHM_WORLD'] < 2) & (sourceTable['XWIN_IMAGE']<3500) & (sourceTable['XWIN_IMAGE']>500) & (sourceTable['YWIN_IMAGE']<3500) & (sourceTable['YWIN_IMAGE']>500)]
# Out:
# Filename: 20230525184701-216-RA.wcs.proc.fits.cat
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  LDAC_IMHEAD    1 BinTableHDU     12   1R x 1C   [19040A]
#   2  LDAC_OBJECTS    1 BinTableHDU    106   374R x 25C   [729E, 1E, 1E, 1D, 1D, 1E, 1E, 1D, 1D, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1I, 1E, 1E, 10E, 10E, 10E, 10E]
# None
# ['VIGNET', 'X_IMAGE', 'Y_IMAGE', 'XWIN_IMAGE', 'YWIN_IMAGE', 'ERRAWIN_IMAGE', 'ERRBWIN_IMAGE', 'ALPHAWIN_J2000', 'DELTAWIN_J2000', 'FLUX_RADIUS', 'FWHM_WORLD', 'FLUX_AUTO', 'FLUXERR_AUTO', 'SNR_WIN', 'ELONGATION', 'FLUX_MAX', 'MAG_AUTO', 'MAGERR_AUTO', 'FLAGS', 'BACKGROUND', 'CLASS_STAR', 'FLUX_APER', 'FLUXERR_APER', 'MAG_APER', 'MAGERR_APER']
#           VIGNET           X_IMAGE  ...          MAGERR_APER
# ------------------------- --------- ... -----------------------------
#      9.027542 .. 8.841557 2005.6249 ...  0.0022592018 .. 0.0034159245
#   11.043878 .. -10.598225 2417.4963 ... 0.0003139003 .. 0.00031706964
#       -1e+30 .. 11.050509 2682.6013 ...     0.023675406 .. 0.03725436
#      -1e+30 .. -2.6355648 2808.9973 ...       0.0268366 .. 0.07171752
#   -1.7916907 .. 18.164097 2121.4253 ...    0.010487212 .. 0.016048692
#     2.359653 .. 0.2291578 1819.9691 ...     0.035301965 .. 0.10557967
# -10.2524805 .. -1.0226951  2275.525 ...    0.011749554 .. 0.018631205
#   -14.431812 .. 24.988997 1949.0037 ...    0.029053792 .. 0.084816776
#     16.60765 .. 13.395456 2279.9968 ...    0.021385523 .. 0.031481218
# -0.026446044 .. 17.063622 1576.3423 ...   0.0033098625 .. 0.004969532
#                       ...       ... ...                           ...
#    -1.432215 .. -8.131363  2708.054 ...    0.004930538 .. 0.008096133
#    20.417488 .. 2.2763367 1248.6727 ...  0.0012680399 .. 0.0020946607
#     30.48062 .. 22.034224 1223.6835 ...    0.006484399 .. 0.010786091
#   19.127571 .. -5.9220924  2099.769 ...   0.0122628035 .. 0.020569555
#  -10.7728405 .. 16.499594 3464.1445 ...  0.0009917326 .. 0.0016190598
#     18.077127 .. 16.19833 1532.9235 ...    0.020125462 .. 0.036714524
#     -23.74455 .. 8.699498 3474.0579 ...  0.0012345791 .. 0.0020027084
#    14.906529 .. 36.754112 1714.3129 ...     0.011340074 .. 0.01895097
#    26.228544 .. 51.863277 1713.1549 ...     0.029554281 .. 0.02289153
#     7.573461 .. 16.256287 771.49506 ...     0.019878913 .. 0.03179921
#   -5.826115 .. -2.1697145 2046.4711 ...   0.0064101024 .. 0.011358951
# Length = 374 rows

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.gca()
plt.imshow(image, cmap='gray', vmin=zscale[0], vmax=zscale[1])
circles = [plt.Circle((source['XWIN_IMAGE'], source['YWIN_IMAGE']), radius = 10, edgecolor='C1', facecolor='None') for source in cleanSources]
for c in circles:
    ax.add_artist(c)
plt.show()

# %%
psfConfigFile = 'psfex_conf.psfex'

try:
    command = f'psfex -c {psfConfigFile} {catalogName}'
    print(f'Executing command: {command}')
    rval = subprocess.run(command.split(), check=True)
except subprocess.CalledProcessError as err:
    print(f'Could not run psfex with exit error {err}')
# Out:
# Executing command: psfex -c psfex_conf.psfex 20230525184701-216-RA.wcs.proc.fits.cat
# > WARNING: This executable has been compiled using a version of the ATLAS library without support for multithreading. Performance will be degraded.

# %%
psfModelHDU = fits.open('moffat_' + imageName + '.fits')[0]
psfModelData = psfModelHDU.data
mean, median, std = sigma_clipped_stats(psfModelData)

plt.figure(figsize=(6,6))
plt.imshow(psfModelData, vmin=0, vmax=median+20*std, origin='lower')
plt.show()

# %%
psfName = imageName + '.psf'
psfcatalogName = imageName+'.psf.cat'
psfparamName = 'photomPSF.param' # This is a new set of parameters to be obtained from SExtractor, including PSF-fit magnitudes
try:
    # We are supplying SExtactor with the PSF model with the PSF_NAME option
    command = f'sex -c {configFile} {imageName} -CATALOG_NAME {psfcatalogName} -PSF_NAME {psfName} -PARAMETERS_NAME {psfparamName}'
    print(f"Executing command: {command}")
    rval = subprocess.run(command.split(), check=True)
except subprocess.CalledProcessError as err:
    print(f'Could not run sextractor with exit error {err}')
# Out:
# Executing command: sex -c photomCat.sex 20230525184701-216-RA.wcs.proc.fits -CATALOG_NAME 20230525184701-216-RA.wcs.proc.fits.psf.cat -PSF_NAME 20230525184701-216-RA.wcs.proc.fits.psf -PARAMETERS_NAME photomPSF.param
# >
# ----- SExtractor 2.28.0 started on 2024-06-24 at 21:20:57 with 1 thread
#
# > Setting catalog parameters
# > Reading PSF information
# > Preparing profile models
# Fitting model: point source
# > Reading detection filter
# > Initializing Neural Network
# > Reading Neural Network Weights
# > Initializing catalog
# > Looking for 20230525184701-216-RA.wcs.proc.fits
# ----- Measuring from: 20230525184701-216-RA.wcs.proc.fits
#       "SN2023ixf" / no ext. header / 4096x4108 / 64 bits (floats)
# Detection+Measurement image: > Setting up background maps
# > Setting up background map at line: 1024
# > Setting up background map at line: 2048
# > Setting up background map at line: 3072
# > Setting up background map at line: 4096
# > Filtering background map(s)
# > Computing background d-map
# > Computing background-noise d-map
# (M+D) Background: 0          RMS: 11.3107    / Threshold: 113.107
# > Scanning image
# > Line:    1  Objects:        0 detected /        0 sextracted
# > Line:    2  Objects:        0 detected /        0 sextracted
# > Line:    3  Objects:        0 detected /        0 sextracted
# > Line:    4  Objects:        0 detected /        0 sextracted
# > Line:    5  Objects:        1 detected /        0 sextracted
# > Line:    6  Objects:        1 detected /        0 sextracted
# > Line:    7  Objects:        1 detected /        0 sextracted
# > Line:    8  Objects:        1 detected /        0 sextracted
# > Line:    9  Objects:        2 detected /        0 sextracted
# > Line:   10  Objects:        2 detected /        0 sextracted
# > Line:   11  Objects:        2 detected /        0 sextracted
# > Line:   12  Objects:        2 detected /        0 sextracted
# > Line:   13  Objects:        2 detected /        0 sextracted
# > Line:   14  Objects:        2 detected /        0 sextracted
# > Line:   15  Objects:        2 detected /        0 sextracted
# > Line:   16  Objects:        2 detected /        0 sextracted
# > Line:   17  Objects:        3 detected /        0 sextracted
# > Line:   18  Objects:        3 detected /        0 sextracted
# > Line:   19  Objects:        3 detected /        0 sextracted
# > Line:   20  Objects:        3 detected /        0 sextracted
# > Line:   21  Objects:        3 detected /        0 sextracted
# > Line:   22  Objects:        3 detected /        0 sextracted
# > Line:   23  Objects:        4 detected /        0 sextracted
# > Line:   24  Objects:        4 detected /        0 sextracted
# > Line:   25  Objects:        4 detected /        0 sextracted
# > Line:   26  Objects:        4 detected /        0 sextracted
# > Line:   27  Objects:        4 detected /        0 sextracted
# > Line:   28  Objects:        4 detected /        0 sextracted
# > Line:   29  Objects:        4 detected /        0 sextracted
# > Line:   30  Objects:        4 detected /        0 sextracted
# > Line:   31  Objects:        4 detected /        0 sextracted
# > Line:   32  Objects:        4 detected /        0 sextracted
# > Line:   33  Objects:        4 detected /        0 sextracted
# > Line:   34  Objects:        4 detected /        0 sextracted
# > Line:   35  Objects:        4 detected /        0 sextracted
# > Line:   36  Objects:        4 detected /        0 sextracted
# > Line:   37  Objects:        4 detected /        0 sextracted
# > Line:   38  Objects:        4 detected /        0 sextracted
# > Line:   39  Objects:        4 detected /        0 sextracted
# > Line:   40  Objects:        4 detected /        0 sextracted
# > Line:   41  Objects:        4 detected /        0 sextracted
# > Line:   42  Objects:        4 detected /        0 sextracted
# > Line:   43  Objects:        4 detected /        0 sextracted
# > Line:   44  Objects:        4 detected /        0 sextracted
# > Line:   45  Objects:        4 detected /        0 sextracted
# > Line:   46  Objects:        4 detected /        0 sextracted
# > Line:   47  Objects:        4 detected /        0 sextracted
# > Line:   48  Objects:        4 detected /        0 sextracted
# > Line:   49  Objects:        4 detected /        0 sextracted
# > Line:   50  Objects:        4 detected /        0 sextracted
# > Line:   51  Objects:        4 detected /        0 sextracted
# > Line:   52  Objects:        4 detected /        0 sextracted
# > Line:   53  Objects:        4 detected /        0 sextracted
# > Line:   54  Objects:        4 detected /        0 sextracted
# > Line:   55  Objects:        4 detected /        0 sextracted
# > Line:   56  Objects:        5 detected /        0 sextracted
# > Line:   57  Objects:        5 detected /        0 sextracted
# > Line:   58  Objects:        5 detected /        0 sextracted
# > Line:   59  Objects:        5 detected /        0 sextracted
# > Line:   60  Objects:        5 detected /        0 sextracted
# > Line:   61  Objects:        5 detected /        0 sextracted
# > Line:   62  Objects:        5 detected /        0 sextracted
# > Line:   63  Objects:        5 detected /        0 sextracted
# > Line:   64  Objects:        5 detected /        0 sextracted
# > Line:   65  Objects:        5 detected /        0 sextracted
# > Line:   66  Objects:        5 detected /        0 sextracted
# > Line:   67  Objects:        5 detected /        0 sextracted
# > Line:   68  Objects:        5 detected /        0 sextracted
# > Line:   69  Objects:        5 detected /        0 sextracted
# > Line:   70  Objects:        5 detected /        0 sextracted
# > Line:   71  Objects:        5 detected /        0 sextracted
# > Line:   72  Objects:        5 detected /        0 sextracted
# > Line:   73  Objects:        5 detected /        0 sextracted
# > Line:   74  Objects:        5 detected /        0 sextracted
# > Line:   75  Objects:        5 detected /        0 sextracted
# > Line:   76  Objects:        5 detected /        0 sextracted
# > Line:   77  Objects:        5 detected /        0 sextracted
# > Line:   78  Objects:        5 detected /        0 sextracted
# > Line:   79  Objects:        5 detected /        0 sextracted
# > Line:   80  Objects:        5 detected /        0 sextracted
# > Line:   81  Objects:        6 detected /        0 sextracted
# > Line:   82  Objects:        6 detected /        0 sextracted
# > Line:   83  Objects:        6 detected /        0 sextracted
# > Line:   84  Objects:        6 detected /        0 sextracted
# > Line:   85  Objects:        6 detected /        0 sextracted
# > Line:   86  Objects:        6 detected /        0 sextracted
# > Line:   87  Objects:        6 detected /        0 sextracted
# > Line:   88  Objects:        6 detected /        0 sextracted
# > Line:   89  Objects:        6 detected /        0 sextracted
# > Line:   90  Objects:        6 detected /        0 sextracted
# > Line:   91  Objects:        6 detected /        0 sextracted
# > Line:   92  Objects:        6 detected /        0 sextracted
# > Line:   93  Objects:        6 detected /        0 sextracted
# > Line:   94  Objects:        6 detected /        0 sextracted
# > Line:   95  Objects:        6 detected /        0 sextracted
# > Line:   96  Objects:        6 detected /        0 sextracted
# > Line:   97  Objects:        6 detected /        0 sextracted
# > Line:   98  Objects:        6 detected /        0 sextracted
# > Line:   99  Objects:        6 detected /        0 sextracted
# > Line:  100  Objects:        6 detected /        0 sextracted
# > Line:  101  Objects:        6 detected /        0 sextracted
# > Line:  102  Objects:        6 detected /        0 sextracted
# > Line:  103  Objects:        6 detected /        0 sextracted
# > Line:  104  Objects:        6 detected /        0 sextracted
# > Line:  105  Objects:        6 detected /        0 sextracted
# > Line:  106  Objects:        6 detected /        0 sextracted
# > Line:  107  Objects:        6 detected /        0 sextracted
# > Line:  108  Objects:        6 detected /        0 sextracted
# > Line:  109  Objects:        6 detected /        0 sextracted
# > Line:  110  Objects:        6 detected /        0 sextracted
# > Line:  111  Objects:        6 detected /        0 sextracted
# > Line:  112  Objects:        6 detected /        0 sextracted
# > Line:  113  Objects:        6 detected /        0 sextracted
# > Line:  114  Objects:        6 detected /        0 sextracted
# > Line:  115  Objects:        6 detected /        0 sextracted
# > Line:  116  Objects:        6 detected /        0 sextracted
# > Line:  117  Objects:        6 detected /        0 sextracted
# > Line:  118  Objects:        6 detected /        0 sextracted
# > Line:  119  Objects:        6 detected /        0 sextracted
# > Line:  120  Objects:        6 detected /        0 sextracted
# > Line:  121  Objects:        6 detected /        0 sextracted
# > Line:  122  Objects:        6 detected /        0 sextracted
# > Line:  123  Objects:        6 detected /        0 sextracted
# > Line:  124  Objects:        6 detected /        0 sextracted
# > Line:  125  Objects:        7 detected /        0 sextracted
# > Line:  126  Objects:        7 detected /        0 sextracted
# > Line:  127  Objects:        8 detected /        0 sextracted
# > Line:  128  Objects:        8 detected /        0 sextracted
# > Line:  129  Objects:        8 detected /        0 sextracted
# > Line:  130  Objects:        8 detected /        0 sextracted
# > Line:  131  Objects:        8 detected /        0 sextracted
# > Line:  132  Objects:        8 detected /        0 sextracted
# > Line:  133  Objects:        8 detected /        0 sextracted
# > Line:  134  Objects:        8 detected /        0 sextracted
# > Line:  135  Objects:        8 detected /        0 sextracted
# > Line:  136  Objects:        8 detected /        0 sextracted
# > Line:  137  Objects:        8 detected /        0 sextracted
# > Line:  138  Objects:        8 detected /        0 sextracted
# > Line:  139  Objects:        8 detected /        0 sextracted
# > Line:  140  Objects:        8 detected /        0 sextracted
# > Line:  141  Objects:        9 detected /        0 sextracted
# > Line:  142  Objects:        9 detected /        0 sextracted
# > Line:  143  Objects:        9 detected /        0 sextracted
# > Line:  144  Objects:        9 detected /        0 sextracted
# > Line:  145  Objects:       10 detected /        0 sextracted
# > Line:  146  Objects:       10 detected /        0 sextracted
# > Line:  147  Objects:       10 detected /        0 sextracted
# > Line:  148  Objects:       10 detected /        0 sextracted
# > Line:  149  Objects:       10 detected /        0 sextracted
# > Line:  150  Objects:       10 detected /        0 sextracted
# > Line:  151  Objects:       10 detected /        0 sextracted
# > Line:  152  Objects:       10 detected /        0 sextracted
# > Line:  153  Objects:       10 detected /        0 sextracted
# > Line:  154  Objects:       10 detected /        0 sextracted
# > Line:  155  Objects:       10 detected /        0 sextracted
# > Line:  156  Objects:       10 detected /        0 sextracted
# > Line:  157  Objects:       11 detected /        0 sextracted
# > Line:  158  Objects:       11 detected /        0 sextracted
# > Line:  159  Objects:       12 detected /        0 sextracted
# > Line:  160  Objects:       12 detected /        0 sextracted
# > Line:  161  Objects:       12 detected /        0 sextracted
# > Line:  162  Objects:       12 detected /        0 sextracted
# > Line:  163  Objects:       12 detected /        0 sextracted
# > Line:  164  Objects:       12 detected /        0 sextracted
# > Line:  165  Objects:       12 detected /        0 sextracted
# > Line:  166  Objects:       12 detected /        0 sextracted
# > Line:  167  Objects:       12 detected /        0 sextracted
# > Line:  168  Objects:       12 detected /        0 sextracted
# > Line:  169  Objects:       12 detected /        0 sextracted
# > Line:  170  Objects:       12 detected /        0 sextracted
# > Line:  171  Objects:       12 detected /        0 sextracted
# > Line:  172  Objects:       12 detected /        0 sextracted
# > Line:  173  Objects:       12 detected /        0 sextracted
# > Line:  174  Objects:       12 detected /        0 sextracted
# > Line:  175  Objects:       12 detected /        0 sextracted
# > Line:  176  Objects:       12 detected /        0 sextracted
# > Line:  177  Objects:       12 detected /        0 sextracted
# > Line:  178  Objects:       12 detected /        0 sextracted
# > Line:  179  Objects:       12 detected /        0 sextracted
# > Line:  180  Objects:       12 detected /        0 sextracted
# > Line:  181  Objects:       12 detected /        0 sextracted
# > Line:  182  Objects:       12 detected /        0 sextracted
# > Line:  183  Objects:       12 detected /        0 sextracted
# > Line:  184  Objects:       12 detected /        0 sextracted
# > Line:  185  Objects:       12 detected /        0 sextracted
# > Line:  186  Objects:       12 detected /        0 sextracted
# > Line:  187  Objects:       12 detected /        0 sextracted
# > Line:  188  Objects:       12 detected /        0 sextracted
# > Line:  189  Objects:       12 detected /        0 sextracted
# > Line:  190  Objects:       12 detected /        0 sextracted
# > Line:  191  Objects:       12 detected /        0 sextracted
# > Line:  192  Objects:       13 detected /        0 sextracted
# > Line:  193  Objects:       13 detected /        0 sextracted
# > Line:  194  Objects:       13 detected /        0 sextracted
# > Line:  195  Objects:       13 detected /        0 sextracted
# > Line:  196  Objects:       14 detected /        0 sextracted
# > Line:  197  Objects:       14 detected /        0 sextracted
# > Line:  198  Objects:       14 detected /        0 sextracted
# > Line:  199  Objects:       14 detected /        0 sextracted
# > Line:  200  Objects:       14 detected /        0 sextracted
# > Line:  201  Objects:       14 detected /        0 sextracted
# > Line:  202  Objects:       14 detected /        0 sextracted
# > Line:  203  Objects:       14 detected /        0 sextracted
# > Line:  204  Objects:       14 detected /        0 sextracted
# > Line:  205  Objects:       14 detected /        0 sextracted
# > Line:  206  Objects:       14 detected /        0 sextracted
# > Line:  207  Objects:       14 detected /        0 sextracted
# > Line:  208  Objects:       14 detected /        0 sextracted
# > Line:  209  Objects:       14 detected /        0 sextracted
# > Line:  210  Objects:       14 detected /        0 sextracted
# > Line:  211  Objects:       14 detected /        0 sextracted
# > Line:  212  Objects:       15 detected /        0 sextracted
# > Line:  213  Objects:       15 detected /        0 sextracted
# > Line:  214  Objects:       15 detected /        0 sextracted
# > Line:  215  Objects:       15 detected /        0 sextracted
# > Line:  216  Objects:       15 detected /        0 sextracted
# > Line:  217  Objects:       15 detected /        0 sextracted
# > Line:  218  Objects:       15 detected /        0 sextracted
# > Line:  219  Objects:       15 detected /        0 sextracted
# > Line:  220  Objects:       15 detected /        0 sextracted
# > Line:  221  Objects:       15 detected /        0 sextracted
# > Line:  222  Objects:       15 detected /        0 sextracted
# > Line:  223  Objects:       15 detected /        0 sextracted
# > Line:  224  Objects:       15 detected /        0 sextracted
# > Line:  225  Objects:       15 detected /        0 sextracted
# > Line:  226  Objects:       15 detected /        0 sextracted
# > Line:  227  Objects:       15 detected /        0 sextracted
# > Line:  228  Objects:       15 detected /        0 sextracted
# > Line:  229  Objects:       15 detected /        0 sextracted
# > Line:  230  Objects:       15 detected /        0 sextracted
# > Line:  231  Objects:       15 detected /        0 sextracted
# > Line:  232  Objects:       15 detected /        0 sextracted
# > Line:  233  Objects:       15 detected /        0 sextracted
# > Line:  234  Objects:       15 detected /        0 sextracted
# > Line:  235  Objects:       15 detected /        0 sextracted
# > Line:  236  Objects:       15 detected /        0 sextracted
# > Line:  237  Objects:       15 detected /        0 sextracted
# > Line:  238  Objects:       15 detected /        0 sextracted
# > Line:  239  Objects:       15 detected /        0 sextracted
# > Line:  240  Objects:       15 detected /        0 sextracted
# > Line:  241  Objects:       15 detected /        0 sextracted
# > Line:  242  Objects:       15 detected /        0 sextracted
# > Line:  243  Objects:       16 detected /        0 sextracted
# > Line:  244  Objects:       16 detected /        0 sextracted
# > Line:  245  Objects:       17 detected /        0 sextracted
# > Line:  246  Objects:       17 detected /        0 sextracted
# > Line:  247  Objects:       17 detected /        0 sextracted
# > Line:  248  Objects:       17 detected /        0 sextracted
# > Line:  249  Objects:       17 detected /        0 sextracted
# > Line:  250  Objects:       17 detected /        0 sextracted
# > Line:  251  Objects:       17 detected /        0 sextracted
# > Line:  252  Objects:       17 detected /        0 sextracted
# > Line:  253  Objects:       17 detected /        0 sextracted
# > Line:  254  Objects:       17 detected /        0 sextracted
# > Line:  255  Objects:       17 detected /        0 sextracted
# > Line:  256  Objects:       17 detected /        0 sextracted
# > Line:  257  Objects:       17 detected /        0 sextracted
# > Line:  258  Objects:       17 detected /        0 sextracted
# > Line:  259  Objects:       17 detected /        0 sextracted
# > Line:  260  Objects:       17 detected /        0 sextracted
# > Line:  261  Objects:       17 detected /        0 sextracted
# > Line:  262  Objects:       17 detected /        0 sextracted
# > Line:  263  Objects:       17 detected /        0 sextracted
# > Line:  264  Objects:       17 detected /        0 sextracted
# > Line:  265  Objects:       17 detected /        0 sextracted
# > Line:  266  Objects:       17 detected /        0 sextracted
# > Line:  267  Objects:       17 detected /        0 sextracted
# > Line:  268  Objects:       17 detected /        0 sextracted
# > Line:  269  Objects:       18 detected /        0 sextracted
# > Line:  270  Objects:       18 detected /        0 sextracted
# > Line:  271  Objects:       18 detected /        0 sextracted
# > Line:  272  Objects:       18 detected /        0 sextracted
# > Line:  273  Objects:       18 detected /        0 sextracted
# > Line:  274  Objects:       18 detected /        0 sextracted
# > Line:  275  Objects:       18 detected /        0 sextracted
# > Line:  276  Objects:       18 detected /        0 sextracted
# > Line:  277  Objects:       18 detected /        0 sextracted
# > Line:  278  Objects:       18 detected /        0 sextracted
# > Line:  279  Objects:       18 detected /        0 sextracted
# > Line:  280  Objects:       19 detected /        0 sextracted
# > Line:  281  Objects:       19 detected /        0 sextracted
# > Line:  282  Objects:       19 detected /        0 sextracted
# > Line:  283  Objects:       19 detected /        0 sextracted
# > Line:  284  Objects:       19 detected /        0 sextracted
# > Line:  285  Objects:       19 detected /        0 sextracted
# > Line:  286  Objects:       19 detected /        0 sextracted
# > Line:  287  Objects:       19 detected /        0 sextracted
# > Line:  288  Objects:       19 detected /        0 sextracted
# > Line:  289  Objects:       19 detected /        0 sextracted
# > Line:  290  Objects:       19 detected /        0 sextracted
# > Line:  291  Objects:       19 detected /        0 sextracted
# > Line:  292  Objects:       19 detected /        0 sextracted
# > Line:  293  Objects:       19 detected /        0 sextracted
# > Line:  294  Objects:       19 detected /        0 sextracted
# > Line:  295  Objects:       19 detected /        0 sextracted
# > Line:  296  Objects:       19 detected /        0 sextracted
# > Line:  297  Objects:       19 detected /        0 sextracted
# > Line:  298  Objects:       19 detected /        0 sextracted
# > Line:  299  Objects:       19 detected /        0 sextracted
# > Line:  300  Objects:       19 detected /        0 sextracted
# > Line:  301  Objects:       19 detected /        0 sextracted
# > Line:  302  Objects:       20 detected /        0 sextracted
# > Line:  303  Objects:       20 detected /        0 sextracted
# > Line:  304  Objects:       20 detected /        0 sextracted
# > Line:  305  Objects:       20 detected /        0 sextracted
# > Line:  306  Objects:       21 detected /        0 sextracted
# > Line:  307  Objects:       21 detected /        0 sextracted
# > Line:  308  Objects:       21 detected /        0 sextracted
# > Line:  309  Objects:       21 detected /        0 sextracted
# > Line:  310  Objects:       21 detected /        0 sextracted
# > Line:  311  Objects:       21 detected /        0 sextracted
# > Line:  312  Objects:       21 detected /        0 sextracted
# > Line:  313  Objects:       21 detected /        0 sextracted
# > Line:  314  Objects:       21 detected /        0 sextracted
# > Line:  315  Objects:       21 detected /        0 sextracted
# > Line:  316  Objects:       21 detected /        0 sextracted
# > Line:  317  Objects:       22 detected /        0 sextracted
# > Line:  318  Objects:       22 detected /        0 sextracted
# > Line:  319  Objects:       22 detected /        0 sextracted
# > Line:  320  Objects:       22 detected /        0 sextracted
# > Line:  321  Objects:       22 detected /        0 sextracted
# > Line:  322  Objects:       22 detected /        0 sextracted
# > Line:  323  Objects:       22 detected /        0 sextracted
# > Line:  324  Objects:       22 detected /        0 sextracted
# > Line:  325  Objects:       22 detected /        0 sextracted
# > Line:  326  Objects:       22 detected /        0 sextracted
# > Line:  327  Objects:       22 detected /        0 sextracted
# > Line:  328  Objects:       22 detected /        0 sextracted
# > Line:  329  Objects:       22 detected /        0 sextracted
# > Line:  330  Objects:       22 detected /        0 sextracted
# > Line:  331  Objects:       22 detected /        0 sextracted
# > Line:  332  Objects:       22 detected /        0 sextracted
# > Line:  333  Objects:       22 detected /        0 sextracted
# > Line:  334  Objects:       22 detected /        0 sextracted
# > Line:  335  Objects:       22 detected /        0 sextracted
# > Line:  336  Objects:       22 detected /        0 sextracted
# > Line:  337  Objects:       22 detected /        0 sextracted
# > Line:  338  Objects:       23 detected /        0 sextracted
# > Line:  339  Objects:       23 detected /        0 sextracted
# > Line:  340  Objects:       23 detected /        0 sextracted
# > Line:  341  Objects:       23 detected /        0 sextracted
# > Line:  342  Objects:       23 detected /        0 sextracted
# > Line:  343  Objects:       23 detected /        0 sextracted
# > Line:  344  Objects:       23 detected /        0 sextracted
# > Line:  345  Objects:       23 detected /        0 sextracted
# > Line:  346  Objects:       23 detected /        0 sextracted
# > Line:  347  Objects:       23 detected /        0 sextracted
# > Line:  348  Objects:       23 detected /        0 sextracted
# > Line:  349  Objects:       23 detected /        0 sextracted
# > Line:  350  Objects:       23 detected /        0 sextracted
# > Line:  351  Objects:       23 detected /        0 sextracted
# > Line:  352  Objects:       23 detected /        0 sextracted
# > Line:  353  Objects:       23 detected /        0 sextracted
# > Line:  354  Objects:       23 detected /        0 sextracted
# > Line:  355  Objects:       23 detected /        0 sextracted
# > Line:  356  Objects:       23 detected /        0 sextracted
# > Line:  357  Objects:       23 detected /        0 sextracted
# > Line:  358  Objects:       23 detected /        0 sextracted
# > Line:  359  Objects:       23 detected /        0 sextracted
# > Line:  360  Objects:       23 detected /        0 sextracted
# > Line:  361  Objects:       23 detected /        0 sextracted
# > Line:  362  Objects:       23 detected /        0 sextracted
# > Line:  363  Objects:       24 detected /        0 sextracted
# > Line:  364  Objects:       24 detected /        0 sextracted
# > Line:  365  Objects:       24 detected /        0 sextracted
# > Line:  366  Objects:       24 detected /        0 sextracted
# > Line:  367  Objects:       24 detected /        0 sextracted
# > Line:  368  Objects:       24 detected /        0 sextracted
# > Line:  369  Objects:       24 detected /        0 sextracted
# > Line:  370  Objects:       25 detected /        0 sextracted
# > Line:  371  Objects:       25 detected /        0 sextracted
# > Line:  372  Objects:       25 detected /        0 sextracted
# > Line:  373  Objects:       26 detected /        0 sextracted
# > Line:  374  Objects:       26 detected /        0 sextracted
# > Line:  375  Objects:       26 detected /        0 sextracted
# > Line:  376  Objects:       26 detected /        0 sextracted
# > Line:  377  Objects:       26 detected /        0 sextracted
# > Line:  378  Objects:       26 detected /        0 sextracted
# > Line:  379  Objects:       26 detected /        0 sextracted
# > Line:  380  Objects:       26 detected /        0 sextracted
# > Line:  381  Objects:       26 detected /        0 sextracted
# > Line:  382  Objects:       26 detected /        0 sextracted
# > Line:  383  Objects:       26 detected /        0 sextracted
# > Line:  384  Objects:       27 detected /        0 sextracted
# > Line:  385  Objects:       27 detected /        0 sextracted
# > Line:  386  Objects:       27 detected /        0 sextracted
# > Line:  387  Objects:       27 detected /        0 sextracted
# > Line:  388  Objects:       27 detected /        0 sextracted
# > Line:  389  Objects:       27 detected /        0 sextracted
# > Line:  390  Objects:       27 detected /        0 sextracted
# > Line:  391  Objects:       27 detected /        0 sextracted
# > Line:  392  Objects:       27 detected /        0 sextracted
# > Line:  393  Objects:       27 detected /        0 sextracted
# > Line:  394  Objects:       27 detected /        0 sextracted
# > Line:  395  Objects:       27 detected /        0 sextracted
# > Line:  396  Objects:       27 detected /        0 sextracted
# > Line:  397  Objects:       27 detected /        0 sextracted
# > Line:  398  Objects:       27 detected /        0 sextracted
# > Line:  399  Objects:       27 detected /        0 sextracted
# > Line:  400  Objects:       28 detected /        0 sextracted
# > Line:  401  Objects:       29 detected /        0 sextracted
# > Line:  402  Objects:       29 detected /        0 sextracted
# > Line:  403  Objects:       29 detected /        0 sextracted
# > Line:  404  Objects:       29 detected /        0 sextracted
# > Line:  405  Objects:       29 detected /        0 sextracted
# > Line:  406  Objects:       29 detected /        0 sextracted
# > Line:  407  Objects:       29 detected /        0 sextracted
# > Line:  408  Objects:       30 detected /        0 sextracted
# > Line:  409  Objects:       30 detected /        0 sextracted
# > Line:  410  Objects:       30 detected /        0 sextracted
# > Line:  411  Objects:       30 detected /        0 sextracted
# > Line:  412  Objects:       30 detected /        0 sextracted
# > Line:  413  Objects:       30 detected /        0 sextracted
# > Line:  414  Objects:       30 detected /        0 sextracted
# > Line:  415  Objects:       30 detected /        0 sextracted
# > Line:  416  Objects:       30 detected /        0 sextracted
# > Line:  417  Objects:       30 detected /        0 sextracted
# > Line:  418  Objects:       30 detected /        0 sextracted
# > Line:  419  Objects:       30 detected /        0 sextracted
# > Line:  420  Objects:       30 detected /        0 sextracted
# > Line:  421  Objects:       30 detected /        0 sextracted
# > Line:  422  Objects:       30 detected /        0 sextracted
# > Line:  423  Objects:       30 detected /        0 sextracted
# > Line:  424  Objects:       30 detected /        0 sextracted
# > Line:  425  Objects:       30 detected /        0 sextracted
# > Line:  426  Objects:       30 detected /        0 sextracted
# > Line:  427  Objects:       30 detected /        0 sextracted
# > Line:  428  Objects:       30 detected /        0 sextracted
# > Line:  429  Objects:       30 detected /        0 sextracted
# > Line:  430  Objects:       30 detected /        0 sextracted
# > Line:  431  Objects:       30 detected /        0 sextracted
# > Line:  432  Objects:       30 detected /        0 sextracted
# > Line:  433  Objects:       30 detected /        0 sextracted
# > Line:  434  Objects:       31 detected /        0 sextracted
# > Line:  435  Objects:       31 detected /        0 sextracted
# > Line:  436  Objects:       31 detected /        0 sextracted
# > Line:  437  Objects:       31 detected /        0 sextracted
# > Line:  438  Objects:       31 detected /        0 sextracted
# > Line:  439  Objects:       31 detected /        0 sextracted
# > Line:  440  Objects:       31 detected /        0 sextracted
# > Line:  441  Objects:       31 detected /        0 sextracted
# > Line:  442  Objects:       31 detected /        0 sextracted
# > Line:  443  Objects:       31 detected /        0 sextracted
# > Line:  444  Objects:       31 detected /        0 sextracted
# > Line:  445  Objects:       31 detected /        0 sextracted
# > Line:  446  Objects:       32 detected /        0 sextracted
# > Line:  447  Objects:       32 detected /        0 sextracted
# > Line:  448  Objects:       32 detected /        0 sextracted
# > Line:  449  Objects:       32 detected /        0 sextracted
# > Line:  450  Objects:       32 detected /        0 sextracted
# > Line:  451  Objects:       32 detected /        0 sextracted
# > Line:  452  Objects:       32 detected /        0 sextracted
# > Line:  453  Objects:       32 detected /        0 sextracted
# > Line:  454  Objects:       32 detected /        0 sextracted
# > Line:  455  Objects:       32 detected /        0 sextracted
# > Line:  456  Objects:       32 detected /        0 sextracted
# > Line:  457  Objects:       32 detected /        0 sextracted
# > Line:  458  Objects:       32 detected /        0 sextracted
# > Line:  459  Objects:       32 detected /        0 sextracted
# > Line:  460  Objects:       32 detected /        0 sextracted
# > Line:  461  Objects:       32 detected /        0 sextracted
# > Line:  462  Objects:       32 detected /        0 sextracted
# > Line:  463  Objects:       32 detected /        0 sextracted
# > Line:  464  Objects:       32 detected /        0 sextracted
# > Line:  465  Objects:       33 detected /        0 sextracted
# > Line:  466  Objects:       33 detected /        0 sextracted
# > Line:  467  Objects:       33 detected /        0 sextracted
# > Line:  468  Objects:       33 detected /        0 sextracted
# > Line:  469  Objects:       33 detected /        0 sextracted
# > Line:  470  Objects:       33 detected /        0 sextracted
# > Line:  471  Objects:       33 detected /        0 sextracted
# > Line:  472  Objects:       33 detected /        0 sextracted
# > Line:  473  Objects:       33 detected /        0 sextracted
# > Line:  474  Objects:       33 detected /        0 sextracted
# > Line:  475  Objects:       33 detected /        0 sextracted
# > Line:  476  Objects:       33 detected /        0 sextracted
# > Line:  477  Objects:       33 detected /        0 sextracted
# > Line:  478  Objects:       33 detected /        0 sextracted
# > Line:  479  Objects:       34 detected /        0 sextracted
# > Line:  480  Objects:       35 detected /        0 sextracted
# > Line:  481  Objects:       35 detected /        0 sextracted
# > Line:  482  Objects:       35 detected /        0 sextracted
# > Line:  483  Objects:       35 detected /        0 sextracted
# > Line:  484  Objects:       35 detected /        0 sextracted
# > Line:  485  Objects:       35 detected /        0 sextracted
# > Line:  486  Objects:       35 detected /        0 sextracted
# > Line:  487  Objects:       35 detected /        0 sextracted
# > Line:  488  Objects:       35 detected /        0 sextracted
# > Line:  489  Objects:       35 detected /        0 sextracted
# > Line:  490  Objects:       35 detected /        0 sextracted
# > Line:  491  Objects:       35 detected /        0 sextracted
# > Line:  492  Objects:       35 detected /        0 sextracted
# > Line:  493  Objects:       35 detected /        0 sextracted
# > Line:  494  Objects:       35 detected /        0 sextracted
# > Line:  495  Objects:       35 detected /        0 sextracted
# > Line:  496  Objects:       35 detected /        0 sextracted
# > Line:  497  Objects:       35 detected /        0 sextracted
# > Line:  498  Objects:       35 detected /        0 sextracted
# > Line:  499  Objects:       35 detected /        0 sextracted
# > Line:  500  Objects:       35 detected /        0 sextracted
# > Line:  501  Objects:       35 detected /        0 sextracted
# > Line:  502  Objects:       35 detected /        0 sextracted
# > Line:  503  Objects:       35 detected /        0 sextracted
# > Line:  504  Objects:       35 detected /        0 sextracted
# > Line:  505  Objects:       35 detected /        0 sextracted
# > Line:  506  Objects:       35 detected /        0 sextracted
# > Line:  507  Objects:       35 detected /        0 sextracted
# > Line:  508  Objects:       35 detected /        0 sextracted
# > Line:  509  Objects:       35 detected /        0 sextracted
# > Line:  510  Objects:       35 detected /        0 sextracted
# > Line:  511  Objects:       35 detected /        0 sextracted
# > Line:  512  Objects:       35 detected /        0 sextracted
# > Line:  513  Objects:       35 detected /        0 sextracted
# > Line:  514  Objects:       35 detected /        0 sextracted
# > Line:  515  Objects:       36 detected /        0 sextracted
# > Line:  516  Objects:       36 detected /        0 sextracted
# > Line:  517  Objects:       36 detected /        0 sextracted
# > Line:  518  Objects:       36 detected /        0 sextracted
# > Line:  519  Objects:       36 detected /        0 sextracted
# > Line:  520  Objects:       36 detected /        0 sextracted
# > Line:  521  Objects:       37 detected /        0 sextracted
# > Line:  522  Objects:       37 detected /        0 sextracted
# > Line:  523  Objects:       37 detected /        0 sextracted
# > Line:  524  Objects:       37 detected /        0 sextracted
# > Line:  525  Objects:       37 detected /        0 sextracted
# > Line:  526  Objects:       37 detected /        0 sextracted
# > Line:  527  Objects:       37 detected /        0 sextracted
# > Line:  528  Objects:       38 detected /        0 sextracted
# > Line:  529  Objects:       38 detected /        0 sextracted
# > Line:  530  Objects:       38 detected /        0 sextracted
# > Line:  531  Objects:       38 detected /        0 sextracted
# > Line:  532  Objects:       38 detected /        0 sextracted
# > Line:  533  Objects:       38 detected /        0 sextracted
# > Line:  534  Objects:       38 detected /        0 sextracted
# > Line:  535  Objects:       38 detected /        0 sextracted
# > Line:  536  Objects:       38 detected /        0 sextracted
# > Line:  537  Objects:       38 detected /        0 sextracted
# > Line:  538  Objects:       39 detected /        0 sextracted
# > Line:  539  Objects:       39 detected /        0 sextracted
# > Line:  540  Objects:       39 detected /        0 sextracted
# > Line:  541  Objects:       39 detected /        0 sextracted
# > Line:  542  Objects:       40 detected /        0 sextracted
# > Line:  543  Objects:       40 detected /        0 sextracted
# > Line:  544  Objects:       40 detected /        0 sextracted
# > Line:  545  Objects:       41 detected /        0 sextracted
# > Line:  546  Objects:       41 detected /        0 sextracted
# > Line:  547  Objects:       41 detected /        0 sextracted
# > Line:  548  Objects:       41 detected /        0 sextracted
# > Line:  549  Objects:       41 detected /        0 sextracted
# > Line:  550  Objects:       41 detected /        0 sextracted
# > Line:  551  Objects:       41 detected /        0 sextracted
# > Line:  552  Objects:       41 detected /        0 sextracted
# > Line:  553  Objects:       41 detected /        0 sextracted
# > Line:  554  Objects:       41 detected /        0 sextracted
# > Line:  555  Objects:       41 detected /        0 sextracted
# > Line:  556  Objects:       41 detected /        0 sextracted
# > Line:  557  Objects:       41 detected /        0 sextracted
# > Line:  558  Objects:       41 detected /        0 sextracted
# > Line:  559  Objects:       41 detected /        0 sextracted
# > Line:  560  Objects:       41 detected /        0 sextracted
# > Line:  561  Objects:       42 detected /        0 sextracted
# > Line:  562  Objects:       42 detected /        0 sextracted
# > Line:  563  Objects:       42 detected /        0 sextracted
# > Line:  564  Objects:       42 detected /        0 sextracted
# > Line:  565  Objects:       42 detected /        0 sextracted
# > Line:  566  Objects:       42 detected /        0 sextracted
# > Line:  567  Objects:       42 detected /        0 sextracted
# > Line:  568  Objects:       42 detected /        0 sextracted
# > Line:  569  Objects:       42 detected /        0 sextracted
# > Line:  570  Objects:       42 detected /        0 sextracted
# > Line:  571  Objects:       43 detected /        0 sextracted
# > Line:  572  Objects:       43 detected /        0 sextracted
# > Line:  573  Objects:       43 detected /        0 sextracted
# > Line:  574  Objects:       43 detected /        0 sextracted
# > Line:  575  Objects:       43 detected /        0 sextracted
# > Line:  576  Objects:       43 detected /        0 sextracted
# > Line:  577  Objects:       43 detected /        0 sextracted
# > Line:  578  Objects:       43 detected /        0 sextracted
# > Line:  579  Objects:       43 detected /        0 sextracted
# > Line:  580  Objects:       43 detected /        0 sextracted
# > Line:  581  Objects:       43 detected /        0 sextracted
# > Line:  582  Objects:       44 detected /        0 sextracted
# > Line:  583  Objects:       44 detected /        0 sextracted
# > Line:  584  Objects:       44 detected /        0 sextracted
# > Line:  585  Objects:       44 detected /        0 sextracted
# > Line:  586  Objects:       44 detected /        0 sextracted
# > Line:  587  Objects:       44 detected /        0 sextracted
# > Line:  588  Objects:       44 detected /        0 sextracted
# > Line:  589  Objects:       45 detected /        0 sextracted
# > Line:  590  Objects:       45 detected /        0 sextracted
# > Line:  591  Objects:       45 detected /        0 sextracted
# > Line:  592  Objects:       45 detected /        0 sextracted
# > Line:  593  Objects:       45 detected /        0 sextracted
# > Line:  594  Objects:       45 detected /        0 sextracted
# > Line:  595  Objects:       45 detected /        0 sextracted
# > Line:  596  Objects:       45 detected /        0 sextracted
# > Line:  597  Objects:       45 detected /        0 sextracted
# > Line:  598  Objects:       45 detected /        0 sextracted
# > Line:  599  Objects:       45 detected /        0 sextracted
# > Line:  600  Objects:       45 detected /        0 sextracted
# > Line:  601  Objects:       45 detected /        0 sextracted
# > Line:  602  Objects:       45 detected /        0 sextracted
# > Line:  603  Objects:       45 detected /        0 sextracted
# > Line:  604  Objects:       45 detected /        0 sextracted
# > Line:  605  Objects:       45 detected /        0 sextracted
# > Line:  606  Objects:       47 detected /        0 sextracted
# > Line:  607  Objects:       47 detected /        0 sextracted
# > Line:  608  Objects:       47 detected /        0 sextracted
# > Line:  609  Objects:       47 detected /        0 sextracted
# > Line:  610  Objects:       47 detected /        0 sextracted
# > Line:  611  Objects:       47 detected /        0 sextracted
# > Line:  612  Objects:       47 detected /        0 sextracted
# > Line:  613  Objects:       47 detected /        0 sextracted
# > Line:  614  Objects:       47 detected /        0 sextracted
# > Line:  615  Objects:       47 detected /        0 sextracted
# > Line:  616  Objects:       47 detected /        0 sextracted
# > Line:  617  Objects:       47 detected /        0 sextracted
# > Line:  618  Objects:       47 detected /        0 sextracted
# > Line:  619  Objects:       47 detected /        0 sextracted
# > Line:  620  Objects:       47 detected /        0 sextracted
# > Line:  621  Objects:       47 detected /        0 sextracted
# > Line:  622  Objects:       47 detected /        0 sextracted
# > Line:  623  Objects:       47 detected /        0 sextracted
# > Line:  624  Objects:       47 detected /        0 sextracted
# > Line:  625  Objects:       47 detected /        0 sextracted
# > Line:  626  Objects:       47 detected /        0 sextracted
# > Line:  627  Objects:       47 detected /        0 sextracted
# > Line:  628  Objects:       47 detected /        0 sextracted
# > Line:  629  Objects:       47 detected /        0 sextracted
# > Line:  630  Objects:       47 detected /        0 sextracted
# > Line:  631  Objects:       47 detected /        0 sextracted
# > Line:  632  Objects:       47 detected /        0 sextracted
# > Line:  633  Objects:       47 detected /        0 sextracted
# > Line:  634  Objects:       47 detected /        0 sextracted
# > Line:  635  Objects:       47 detected /        0 sextracted
# > Line:  636  Objects:       47 detected /        0 sextracted
# > Line:  637  Objects:       47 detected /        0 sextracted
# > Line:  638  Objects:       47 detected /        0 sextracted
# > Line:  639  Objects:       47 detected /        0 sextracted
# > Line:  640  Objects:       47 detected /        0 sextracted
# > Line:  641  Objects:       47 detected /        0 sextracted
# > Line:  642  Objects:       47 detected /        0 sextracted
# > Line:  643  Objects:       47 detected /        0 sextracted
# > Line:  644  Objects:       47 detected /        0 sextracted
# > Line:  645  Objects:       47 detected /        0 sextracted
# > Line:  646  Objects:       47 detected /        0 sextracted
# > Line:  647  Objects:       47 detected /        0 sextracted
# > Line:  648  Objects:       47 detected /        0 sextracted
# > Line:  649  Objects:       47 detected /        0 sextracted
# > Line:  650  Objects:       47 detected /        0 sextracted
# > Line:  651  Objects:       47 detected /        0 sextracted
# > Line:  652  Objects:       47 detected /        0 sextracted
# > Line:  653  Objects:       47 detected /        0 sextracted
# > Line:  654  Objects:       49 detected /        0 sextracted
# > Line:  655  Objects:       49 detected /        0 sextracted
# > Line:  656  Objects:       49 detected /        0 sextracted
# > Line:  657  Objects:       49 detected /        0 sextracted
# > Line:  658  Objects:       49 detected /        0 sextracted
# > Line:  659  Objects:       49 detected /        0 sextracted
# > Line:  660  Objects:       49 detected /        0 sextracted
# > Line:  661  Objects:       49 detected /        0 sextracted
# > Line:  662  Objects:       49 detected /        0 sextracted
# > Line:  663  Objects:       49 detected /        0 sextracted
# > Line:  664  Objects:       49 detected /        0 sextracted
# > Line:  665  Objects:       49 detected /        0 sextracted
# > Line:  666  Objects:       49 detected /        0 sextracted
# > Line:  667  Objects:       49 detected /        0 sextracted
# > Line:  668  Objects:       49 detected /        0 sextracted
# > Line:  669  Objects:       49 detected /        0 sextracted
# > Line:  670  Objects:       49 detected /        0 sextracted
# > Line:  671  Objects:       49 detected /        0 sextracted
# > Line:  672  Objects:       49 detected /        0 sextracted
# > Line:  673  Objects:       49 detected /        0 sextracted
# > Line:  674  Objects:       49 detected /        0 sextracted
# > Line:  675  Objects:       49 detected /        0 sextracted
# > Line:  676  Objects:       49 detected /        0 sextracted
# > Line:  677  Objects:       49 detected /        0 sextracted
# > Line:  678  Objects:       49 detected /        0 sextracted
# > Line:  679  Objects:       49 detected /        0 sextracted
# > Line:  680  Objects:       49 detected /        0 sextracted
# > Line:  681  Objects:       49 detected /        0 sextracted
# > Line:  682  Objects:       49 detected /        0 sextracted
# > Line:  683  Objects:       49 detected /        0 sextracted
# > Line:  684  Objects:       49 detected /        0 sextracted
# > Line:  685  Objects:       49 detected /        0 sextracted
# > Line:  686  Objects:       50 detected /        0 sextracted
# > Line:  687  Objects:       50 detected /        0 sextracted
# > Line:  688  Objects:       50 detected /        0 sextracted
# > Line:  689  Objects:       50 detected /        0 sextracted
# > Line:  690  Objects:       50 detected /        0 sextracted
# > Line:  691  Objects:       50 detected /        0 sextracted
# > Line:  692  Objects:       50 detected /        0 sextracted
# > Line:  693  Objects:       50 detected /        0 sextracted
# > Line:  694  Objects:       50 detected /        0 sextracted
# > Line:  695  Objects:       50 detected /        0 sextracted
# > Line:  696  Objects:       50 detected /        0 sextracted
# > Line:  697  Objects:       51 detected /        0 sextracted
# > Line:  698  Objects:       51 detected /        0 sextracted
# > Line:  699  Objects:       51 detected /        0 sextracted
# > Line:  700  Objects:       52 detected /        0 sextracted
# > Line:  701  Objects:       52 detected /        0 sextracted
# > Line:  702  Objects:       53 detected /        0 sextracted
# > Line:  703  Objects:       53 detected /        0 sextracted
# > Line:  704  Objects:       53 detected /        0 sextracted
# > Line:  705  Objects:       53 detected /        0 sextracted
# > Line:  706  Objects:       53 detected /        0 sextracted
# > Line:  707  Objects:       53 detected /        0 sextracted
# > Line:  708  Objects:       53 detected /        0 sextracted
# > Line:  709  Objects:       53 detected /        0 sextracted
# > Line:  710  Objects:       53 detected /        0 sextracted
# > Line:  711  Objects:       53 detected /        0 sextracted
# > Line:  712  Objects:       54 detected /        0 sextracted
# > Line:  713  Objects:       54 detected /        0 sextracted
# > Line:  714  Objects:       54 detected /        0 sextracted
# > Line:  715  Objects:       54 detected /        0 sextracted
# > Line:  716  Objects:       54 detected /        0 sextracted
# > Line:  717  Objects:       54 detected /        0 sextracted
# > Line:  718  Objects:       54 detected /        0 sextracted
# > Line:  719  Objects:       54 detected /        0 sextracted
# > Line:  720  Objects:       55 detected /        0 sextracted
# > Line:  721  Objects:       55 detected /        0 sextracted
# > Line:  722  Objects:       55 detected /        0 sextracted
# > Line:  723  Objects:       55 detected /        0 sextracted
# > Line:  724  Objects:       55 detected /        0 sextracted
# > Line:  725  Objects:       55 detected /        0 sextracted
# > Line:  726  Objects:       55 detected /        0 sextracted
# > Line:  727  Objects:       55 detected /        0 sextracted
# > Line:  728  Objects:       56 detected /        0 sextracted
# > Line:  729  Objects:       56 detected /        0 sextracted
# > Line:  730  Objects:       56 detected /        0 sextracted
# > Line:  731  Objects:       56 detected /        0 sextracted
# > Line:  732  Objects:       56 detected /        0 sextracted
# > Line:  733  Objects:       56 detected /        0 sextracted
# > Line:  734  Objects:       56 detected /        0 sextracted
# > Line:  735  Objects:       56 detected /        0 sextracted
# > Line:  736  Objects:       56 detected /        0 sextracted
# > Line:  737  Objects:       56 detected /        0 sextracted
# > Line:  738  Objects:       56 detected /        0 sextracted
# > Line:  739  Objects:       56 detected /        0 sextracted
# > Line:  740  Objects:       56 detected /        0 sextracted
# > Line:  741  Objects:       56 detected /        0 sextracted
# > Line:  742  Objects:       56 detected /        0 sextracted
# > Line:  743  Objects:       56 detected /        0 sextracted
# > Line:  744  Objects:       56 detected /        0 sextracted
# ...
# > Line: 1692  Objects:      147 detected /       50 sextracted
# > Line: 1700  Objects:      148 detected /       51 sextracted
# > Line: 1725  Objects:      149 detected /       55 sextracted
# > Line: 1750  Objects:      152 detected /       57 sextracted
# > Line: 1775  Objects:      154 detected /       58 sextracted
# > Line: 1799  Objects:      155 detected /       60 sextracted
# > Line: 1800  Objects:      156 detected /       60 sextracted
# > Line: 1801  Objects:      156 detected /       60 sextracted
# > Line: 1802  Objects:      156 detected /       60 sextracted
# > Line: 1825  Objects:      161 detected /       61 sextracted
# > Line: 1850  Objects:      163 detected /       65 sextracted
# > Line: 1875  Objects:      165 detected /       67 sextracted
# > Line: 1900  Objects:      170 detected /       68 sextracted
# > Line: 1919  Objects:      171 detected /       70 sextracted
# > Line: 1920  Objects:      171 detected /       70 sextracted
# > Line: 1921  Objects:      171 detected /       70 sextracted
# > Line: 1922  Objects:      171 detected /       70 sextracted
# > Line: 1925  Objects:      171 detected /       71 sextracted
# > Line: 1950  Objects:      174 detected /       74 sextracted
# > Line: 1975  Objects:      177 detected /       77 sextracted
# > Line: 2000  Objects:      178 detected /       78 sextracted
# > Line: 2014  Objects:      178 detected /       80 sextracted
# > Line: 2015  Objects:      178 detected /       80 sextracted
# > Line: 2016  Objects:      179 detected /       80 sextracted
# > Line: 2017  Objects:      179 detected /       80 sextracted
# > Line: 2018  Objects:      179 detected /       80 sextracted
# > Line: 2019  Objects:      180 detected /       80 sextracted
# > Line: 2020  Objects:      180 detected /       80 sextracted
# > Line: 2021  Objects:      180 detected /       80 sextracted
# > Line: 2022  Objects:      180 detected /       80 sextracted
# > Line: 2023  Objects:      181 detected /       80 sextracted
# > Line: 2024  Objects:      181 detected /       80 sextracted
# > Line: 2025  Objects:      181 detected /       80 sextracted
# > Line: 2025  Objects:      181 detected /       81 sextracted
# > Line: 2050  Objects:      183 detected /       83 sextracted
# > Line: 2075  Objects:      185 detected /       87 sextracted
# > Line: 2096  Objects:      187 detected /       90 sextracted
# > Line: 2097  Objects:      187 detected /       90 sextracted
# > Line: 2098  Objects:      187 detected /       90 sextracted
# > Line: 2099  Objects:      187 detected /       90 sextracted
# > Line: 2100  Objects:      187 detected /       90 sextracted
# > Line: 2100  Objects:      187 detected /       91 sextracted
# > Line: 2125  Objects:      193 detected /       91 sextracted
# > Line: 2150  Objects:      194 detected /       91 sextracted
# > Line: 2175  Objects:      198 detected /       93 sextracted
# > Line: 2200  Objects:      202 detected /       97 sextracted
# > Line: 2225  Objects:      203 detected /       98 sextracted
# > Line: 2250  Objects:      206 detected /       99 sextracted
# > Line: 2254  Objects:      207 detected /      100 sextracted
# > Line: 2255  Objects:      207 detected /      100 sextracted
# > Line: 2256  Objects:      207 detected /      100 sextracted
# > Line: 2257  Objects:      207 detected /      100 sextracted
# > Line: 2258  Objects:      208 detected /      100 sextracted
# > Line: 2275  Objects:      210 detected /      105 sextracted
# > Line: 2300  Objects:      213 detected /      106 sextracted
# > Line: 2318  Objects:      215 detected /      110 sextracted
# > Line: 2319  Objects:      215 detected /      110 sextracted
# > Line: 2320  Objects:      215 detected /      110 sextracted
# > Line: 2321  Objects:      215 detected /      110 sextracted
# > Line: 2322  Objects:      215 detected /      110 sextracted
# > Line: 2325  Objects:      216 detected /      111 sextracted
# > Line: 2350  Objects:      220 detected /      115 sextracted
# > Line: 2375  Objects:      220 detected /      115 sextracted
# > Line: 2400  Objects:      223 detected /      117 sextracted
# > Line: 2423  Objects:      223 detected /      120 sextracted
# > Line: 2424  Objects:      223 detected /      120 sextracted
# > Line: 2425  Objects:      223 detected /      120 sextracted
# > Line: 2426  Objects:      223 detected /      120 sextracted
# > Line: 2427  Objects:      223 detected /      120 sextracted
# > Line: 2428  Objects:      223 detected /      120 sextracted
# > Line: 2429  Objects:      223 detected /      120 sextracted
# > Line: 2430  Objects:      223 detected /      120 sextracted
# > Line: 2431  Objects:      223 detected /      120 sextracted
# > Line: 2432  Objects:      223 detected /      120 sextracted
# > Line: 2433  Objects:      223 detected /      120 sextracted
# > Line: 2434  Objects:      223 detected /      120 sextracted
# > Line: 2435  Objects:      223 detected /      120 sextracted
# > Line: 2436  Objects:      223 detected /      120 sextracted
# > Line: 2437  Objects:      223 detected /      120 sextracted
# > Line: 2438  Objects:      223 detected /      120 sextracted
# > Line: 2439  Objects:      223 detected /      120 sextracted
# > Line: 2440  Objects:      223 detected /      120 sextracted
# > Line: 2441  Objects:      223 detected /      120 sextracted
# > Line: 2442  Objects:      223 detected /      120 sextracted
# > Line: 2450  Objects:      223 detected /      122 sextracted
# > Line: 2475  Objects:      225 detected /      126 sextracted
# > Line: 2500  Objects:      227 detected /      126 sextracted
# > Line: 2512  Objects:      228 detected /      130 sextracted
# > Line: 2513  Objects:      229 detected /      130 sextracted
# > Line: 2514  Objects:      229 detected /      130 sextracted
# > Line: 2525  Objects:      230 detected /      131 sextracted
# > Line: 2550  Objects:      235 detected /      134 sextracted
# > Line: 2575  Objects:      237 detected /      136 sextracted
# > Line: 2600  Objects:      242 detected /      136 sextracted
# > Line: 2617  Objects:      246 detected /      140 sextracted
# > Line: 2618  Objects:      246 detected /      140 sextracted
# > Line: 2619  Objects:      246 detected /      140 sextracted
# > Line: 2625  Objects:      246 detected /      141 sextracted
# > Line: 2650  Objects:      249 detected /      143 sextracted
# > Line: 2675  Objects:      249 detected /      145 sextracted
# > Line: 2700  Objects:      250 detected /      146 sextracted
# > Line: 2725  Objects:      254 detected /      148 sextracted
# > Line: 2740  Objects:      257 detected /      150 sextracted
# > Line: 2750  Objects:      257 detected /      151 sextracted
# > Line: 2775  Objects:      258 detected /      152 sextracted
# > Line: 2800  Objects:      260 detected /      155 sextracted
# > Line: 2825  Objects:      263 detected /      159 sextracted
# > Line: 2846  Objects:      265 detected /      160 sextracted
# > Line: 2847  Objects:      265 detected /      160 sextracted
# > Line: 2848  Objects:      265 detected /      160 sextracted
# > Line: 2849  Objects:      265 detected /      160 sextracted
# > Line: 2850  Objects:      265 detected /      160 sextracted
# > Line: 2851  Objects:      265 detected /      160 sextracted
# > Line: 2852  Objects:      265 detected /      160 sextracted
# > Line: 2875  Objects:      269 detected /      164 sextracted
# > Line: 2900  Objects:      270 detected /      167 sextracted
# > Line: 2925  Objects:      272 detected /      169 sextracted
# > Line: 2941  Objects:      274 detected /      170 sextracted
# > Line: 2942  Objects:      274 detected /      170 sextracted
# > Line: 2943  Objects:      275 detected /      170 sextracted
# > Line: 2950  Objects:      276 detected /      171 sextracted
# > Line: 2975  Objects:      278 detected /      175 sextracted
# > Line: 3000  Objects:      283 detected /      176 sextracted
# > Line: 3025  Objects:      287 detected /      178 sextracted
# > Line: 3032  Objects:      288 detected /      180 sextracted
# > Line: 3033  Objects:      288 detected /      180 sextracted
# > Line: 3034  Objects:      288 detected /      180 sextracted
# > Line: 3035  Objects:      288 detected /      180 sextracted
# > Line: 3036  Objects:      288 detected /      180 sextracted
# > Line: 3037  Objects:      288 detected /      180 sextracted
# > Line: 3038  Objects:      288 detected /      180 sextracted
# > Line: 3039  Objects:      288 detected /      180 sextracted
# > Line: 3050  Objects:      289 detected /      182 sextracted
# > Line: 3075  Objects:      292 detected /      183 sextracted
# > Line: 3100  Objects:      298 detected /      185 sextracted
# > Line: 3120  Objects:      298 detected /      190 sextracted
# > Line: 3121  Objects:      298 detected /      190 sextracted
# > Line: 3125  Objects:      299 detected /      192 sextracted
# > Line: 3150  Objects:      302 detected /      193 sextracted
# > Line: 3175  Objects:      302 detected /      195 sextracted
# > Line: 3193  Objects:      308 detected /      200 sextracted
# > Line: 3194  Objects:      308 detected /      200 sextracted
# > Line: 3195  Objects:      309 detected /      200 sextracted
# > Line: 3196  Objects:      309 detected /      200 sextracted
# > Line: 3197  Objects:      309 detected /      200 sextracted
# > Line: 3198  Objects:      309 detected /      200 sextracted
# > Line: 3199  Objects:      309 detected /      200 sextracted
# > Line: 3200  Objects:      309 detected /      200 sextracted
# > Line: 3201  Objects:      309 detected /      200 sextracted
# > Line: 3202  Objects:      309 detected /      200 sextracted
# > Line: 3203  Objects:      309 detected /      200 sextracted
# > Line: 3204  Objects:      309 detected /      200 sextracted
# > Line: 3205  Objects:      309 detected /      200 sextracted
# > Line: 3206  Objects:      309 detected /      200 sextracted
# > Line: 3207  Objects:      309 detected /      200 sextracted
# > Line: 3208  Objects:      309 detected /      200 sextracted
# > Line: 3209  Objects:      309 detected /      200 sextracted
# > Line: 3210  Objects:      309 detected /      200 sextracted
# > Line: 3211  Objects:      309 detected /      200 sextracted
# > Line: 3212  Objects:      309 detected /      200 sextracted
# > Line: 3213  Objects:      309 detected /      200 sextracted
# > Line: 3214  Objects:      309 detected /      200 sextracted
# > Line: 3215  Objects:      309 detected /      200 sextracted
# > Line: 3216  Objects:      309 detected /      200 sextracted
# > Line: 3217  Objects:      309 detected /      200 sextracted
# > Line: 3218  Objects:      309 detected /      200 sextracted
# > Line: 3219  Objects:      309 detected /      200 sextracted
# > Line: 3220  Objects:      309 detected /      200 sextracted
# > Line: 3221  Objects:      309 detected /      200 sextracted
# > Line: 3222  Objects:      309 detected /      200 sextracted
# > Line: 3223  Objects:      309 detected /      200 sextracted
# > Line: 3225  Objects:      309 detected /      201 sextracted
# > Line: 3250  Objects:      311 detected /      203 sextracted
# > Line: 3275  Objects:      315 detected /      206 sextracted
# > Line: 3291  Objects:      317 detected /      210 sextracted
# > Line: 3292  Objects:      318 detected /      210 sextracted
# > Line: 3293  Objects:      318 detected /      210 sextracted
# > Line: 3294  Objects:      319 detected /      210 sextracted
# > Line: 3295  Objects:      319 detected /      210 sextracted
# > Line: 3296  Objects:      319 detected /      210 sextracted
# > Line: 3297  Objects:      320 detected /      210 sextracted
# > Line: 3298  Objects:      320 detected /      210 sextracted
# > Line: 3299  Objects:      320 detected /      210 sextracted
# > Line: 3300  Objects:      321 detected /      210 sextracted
# > Line: 3300  Objects:      321 detected /      211 sextracted
# > Line: 3325  Objects:      323 detected /      214 sextracted
# > Line: 3350  Objects:      325 detected /      218 sextracted
# > Line: 3375  Objects:      326 detected /      218 sextracted
# > Line: 3394  Objects:      327 detected /      220 sextracted
# > Line: 3395  Objects:      327 detected /      220 sextracted
# > Line: 3396  Objects:      327 detected /      220 sextracted
# > Line: 3397  Objects:      327 detected /      220 sextracted
# > Line: 3398  Objects:      327 detected /      220 sextracted
# > Line: 3400  Objects:      327 detected /      221 sextracted
# > Line: 3425  Objects:      328 detected /      221 sextracted
# > Line: 3450  Objects:      331 detected /      221 sextracted
# > Line: 3475  Objects:      336 detected /      223 sextracted
# > Line: 3500  Objects:      340 detected /      225 sextracted
# > Line: 3525  Objects:      343 detected /      228 sextracted
# > Line: 3532  Objects:      344 detected /      230 sextracted
# > Line: 3533  Objects:      344 detected /      230 sextracted
# > Line: 3550  Objects:      346 detected /      233 sextracted
# > Line: 3575  Objects:      349 detected /      236 sextracted
# > Line: 3599  Objects:      352 detected /      240 sextracted
# > Line: 3600  Objects:      352 detected /      240 sextracted
# > Line: 3600  Objects:      352 detected /      241 sextracted
# > Line: 3625  Objects:      353 detected /      244 sextracted
# > Line: 3650  Objects:      356 detected /      247 sextracted
# > Line: 3675  Objects:      357 detected /      247 sextracted
# > Line: 3700  Objects:      357 detected /      248 sextracted
# > Line: 3711  Objects:      358 detected /      250 sextracted
# > Line: 3725  Objects:      359 detected /      253 sextracted
# > Line: 3750  Objects:      359 detected /      256 sextracted
# > Line: 3775  Objects:      361 detected /      256 sextracted
# > Line: 3799  Objects:      362 detected /      260 sextracted
# > Line: 3800  Objects:      362 detected /      260 sextracted
# > Line: 3801  Objects:      362 detected /      260 sextracted
# > Line: 3802  Objects:      363 detected /      260 sextracted
# > Line: 3803  Objects:      363 detected /      260 sextracted
# > Line: 3804  Objects:      363 detected /      260 sextracted
# > Line: 3805  Objects:      363 detected /      260 sextracted
# > Line: 3806  Objects:      363 detected /      260 sextracted
# > Line: 3807  Objects:      363 detected /      260 sextracted
# > Line: 3808  Objects:      364 detected /      260 sextracted
# > Line: 3809  Objects:      364 detected /      260 sextracted
# > Line: 3810  Objects:      364 detected /      260 sextracted
# > Line: 3811  Objects:      364 detected /      260 sextracted
# > Line: 3812  Objects:      364 detected /      260 sextracted
# > Line: 3825  Objects:      365 detected /      262 sextracted
# > Line: 3850  Objects:      367 detected /      262 sextracted
# > Line: 3875  Objects:      369 detected /      262 sextracted
# > Line: 3900  Objects:      372 detected /      262 sextracted
# > Line: 3925  Objects:      373 detected /      262 sextracted
# > Line: 3950  Objects:      374 detected /      262 sextracted
# > Line: 3975  Objects:      375 detected /      262 sextracted
# > Line: 4000  Objects:      376 detected /      262 sextracted
# > Line: 4025  Objects:      376 detected /      262 sextracted
# > Line: 4050  Objects:      377 detected /      262 sextracted
# > Line: 4075  Objects:      377 detected /      262 sextracted
# > Line: 4100  Objects:      377 detected /      262 sextracted
# > Line: 4108  Objects:      377 detected /      270 sextracted
# > Line: 4108  Objects:      377 detected /      280 sextracted
# > Line: 4108  Objects:      377 detected /      290 sextracted
# > Line: 4108  Objects:      377 detected /      300 sextracted
# > Line: 4108  Objects:      377 detected /      310 sextracted
# > Line: 4108  Objects:      377 detected /      320 sextracted
# > Line: 4108  Objects:      377 detected /      330 sextracted
# > Line: 4108  Objects:      377 detected /      340 sextracted
# > Line: 4108  Objects:      377 detected /      350 sextracted
# > Line: 4108  Objects:      377 detected /      360 sextracted
# > Line: 4108  Objects:      377 detected /      370 sextracted
#       Objects: detected 377      / sextracted 374
#
# > Closing files
# >
# > All done (in 2.3 s: 1770.9 lines/s , 161.2 detections/s)

# %%
with fits.open(psfcatalogName) as HDU:
    psfsourceTable = Table(HDU[2].data)

print(psfsourceTable.colnames)
print(psfsourceTable)

cleanPSFSources = psfsourceTable[(psfsourceTable['FLAGS']==0) & (psfsourceTable['FLAGS_MODEL']==0)  & (psfsourceTable['FWHM_WORLD'] < 2) & (psfsourceTable['XMODEL_IMAGE']<3500) & (psfsourceTable['XMODEL_IMAGE']>500) &(psfsourceTable['YMODEL_IMAGE']<3500) &(psfsourceTable['YMODEL_IMAGE']>500)]
# Out:
# ['VIGNET', 'X_IMAGE', 'Y_IMAGE', 'XWIN_IMAGE', 'YWIN_IMAGE', 'ERRAWIN_IMAGE', 'ERRBWIN_IMAGE', 'ALPHAWIN_J2000', 'DELTAWIN_J2000', 'FLUX_RADIUS', 'FWHM_WORLD', 'FLUX_AUTO', 'FLUXERR_AUTO', 'SNR_WIN', 'ELONGATION', 'FLUX_MAX', 'MAG_AUTO', 'MAGERR_AUTO', 'FLAGS', 'BACKGROUND', 'CLASS_STAR', 'FLAGS_MODEL', 'NITER_MODEL', 'XMODEL_IMAGE', 'YMODEL_IMAGE', 'FLUX_POINTSOURCE', 'FLUXERR_POINTSOURCE', 'MAG_POINTSOURCE', 'MAGERR_POINTSOURCE', 'FLUXRATIO_POINTSOURCE', 'FLUXRATIOERR_POINTSOURCE']
#           VIGNET           X_IMAGE  ... FLUXRATIOERR_POINTSOURCE
# ------------------------- --------- ... ------------------------
#      9.027542 .. 8.841557 2005.6249 ...                      0.0
#   11.043878 .. -10.598225 2417.4963 ...                      0.0
#       -1e+30 .. 11.050509 2682.6013 ...                      0.0
#      -1e+30 .. -2.6355648 2808.9973 ...                      0.0
#   -1.7916907 .. 18.164097 2121.4253 ...                      0.0
#     2.359653 .. 0.2291578 1819.9691 ...                      0.0
# -10.2524805 .. -1.0226951  2275.525 ...                      0.0
#   -14.431812 .. 24.988997 1949.0037 ...                      0.0
#     16.60765 .. 13.395456 2279.9968 ...                      0.0
# -0.026446044 .. 17.063622 1576.3423 ...                      0.0
#                       ...       ... ...                      ...
#    -1.432215 .. -8.131363  2708.054 ...                      0.0
#    20.417488 .. 2.2763367 1248.6727 ...                      0.0
#     30.48062 .. 22.034224 1223.6835 ...                      0.0
#   19.127571 .. -5.9220924  2099.769 ...                      0.0
#  -10.7728405 .. 16.499594 3464.1445 ...                      0.0
#     18.077127 .. 16.19833 1532.9235 ...                      0.0
#     -23.74455 .. 8.699498 3474.0579 ...                      0.0
#    14.906529 .. 36.754112 1714.3129 ...                      0.0
#    26.228544 .. 51.863277 1713.1549 ...                      0.0
#     7.573461 .. 16.256287 771.49506 ...                      0.0
#   -5.826115 .. -2.1697145 2046.4711 ...                      0.0
# Length = 374 rows

# %%
psfsourceCatCoords = SkyCoord(ra=cleanPSFSources['ALPHAWIN_J2000'], dec=cleanPSFSources['DELTAWIN_J2000'], frame='icrs', unit='degree')
ps1CatCoords = SkyCoord(ra=good_cat_stars['RAJ2000'], dec=good_cat_stars['DEJ2000'], frame='icrs', unit='degree')
photoDistThresh = 0.6
idx_psfimage, idx_psfps1, d2d, d3d = ps1CatCoords.search_around_sky(psfsourceCatCoords, photoDistThresh*u.arcsec)

print(f'Found {len(idx_psfimage)} good cross-matches')
# Out:
# Found 142 good cross-matches

# %%
plt.figure(figsize=(8,8))
plt.scatter(good_cat_stars['gmag'][idx_psfps1], cleanPSFSources['MAG_POINTSOURCE'][idx_psfimage], color='C0', s=10)
plt.xlabel('PS1 magnitude', fontsize=15)
plt.ylabel('Instrumental PSF-fit magnitude', fontsize=15)
plt.show()

# %%
psfoffsets = ma.array(good_cat_stars['gmag'][idx_psfps1] - cleanPSFSources['MAG_POINTSOURCE'][idx_psfimage])
zero_psfmean, zero_psfmed, zero_psfstd = sigma_clipped_stats(psfoffsets)
print('PSF Mean ZP: %.2f\nPSF Median ZP: %.2f\nPSF STD ZP: %.2f'%(zero_psfmean, zero_psfmed, zero_psfstd))
# Out:
# PSF Mean ZP: 25.88
# PSF Median ZP: 26.00
# PSF STD ZP: 0.22
# /Users/divyansh/miniforge3/envs/KSP/lib/python3.11/site-packages/numpy/core/fromnumeric.py:771: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   a.partition(kth, axis=axis, kind=kind, order=order)
# /Users/divyansh/miniforge3/envs/KSP/lib/python3.11/site-packages/numpy/core/fromnumeric.py:771: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   a.partition(kth, axis=axis, kind=kind, order=order)

# %%
ra = 210.910674637
dec = 54.3116510708

sn2023ixf_coords = SkyCoord(ra=[ra], dec=[dec], frame='icrs', unit='degree')
idx_sn2023ixf, idx_cleanpsf_sn2023ixf, d2d, d3d = psfsourceCatCoords.search_around_sky(sn2023ixf_coords, photoDistThresh*u.arcsec)
print(f'Found the source at index {idx_cleanpsf_sn2023ixf[0]}')
# Out:
# Found the source at index 153

# %%
sn2023ixf_psfinstmag = cleanPSFSources[idx_cleanpsf_sn2023ixf]['MAG_POINTSOURCE'][0]
sn2023ixf_psfinstmagerr = cleanPSFSources[idx_cleanpsf_sn2023ixf]['MAGERR_POINTSOURCE'][0]

sn2023ixf_psfmag = zero_psfmed + sn2023ixf_psfinstmag
sn2023ixf_psfmagerr = np.sqrt(sn2023ixf_psfinstmagerr**2 + zero_psfstd**2)

print(f'PSF-fit magnitude of SN2023ixf is {sn2023ixf_psfmag} +/- {sn2023ixf_psfmagerr}')
# Out:
# PSF-fit magnitude of SN2023ixf is 11.038978488922119 +/- 0.21764998526536458
